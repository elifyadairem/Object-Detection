# %% [markdown]
# <a href="https://colab.research.google.com/github/elifyadairem/Object-Detection/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.7/91.7 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 83.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 98.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 129.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="Qq9MpG1JXxkpendiVwc0")
project = rf.workspace("elifyadairem-hmyli").project("vlm-57ozs")
version = project.version(2)
dataset = version.download("yolov8")


print(f"Veri seti şu konuma indi: {dataset.location}")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to VLM-2 in yolov8:: 100%|██████████| 2680/2680 [00:00<00:00, 6715.04it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Veri seti şu konuma indi: /content/VLM-2

# %%
from ultralytics import YOLO


model = YOLO('yolov8s.pt')


model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=20,
    imgsz=640,
    plots=True
)
# Out:
# ...
# Ultralytics 8.4.6 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# Eğitim sonuçlarını listele (Genellikle runs/detect/train klasöründe olur)
# !ls runs/detect/train/

# Modelin başarısını gösteren grafiği ekrana bas
from IPython.display import Image
Image(filename=f'runs/detect/train/results.png', width=600)
# Out:
# args.yaml			 results.csv	     val_batch0_labels.jpg
# BoxF1_curve.png			 results.png	     val_batch0_pred.jpg
# BoxP_curve.png			 train_batch0.jpg    val_batch1_labels.jpg
# BoxPR_curve.png			 train_batch1.jpg    val_batch1_pred.jpg
# BoxR_curve.png			 train_batch2.jpg    val_batch2_labels.jpg
# confusion_matrix_normalized.png  train_batch580.jpg  val_batch2_pred.jpg
# confusion_matrix.png		 train_batch581.jpg  weights
# labels.jpg			 train_batch582.jpg
